# %% [markdown]
# <img src="http://robotics.eecs.berkeley.edu/~ronf/biomimetics-thin.jpg">

# %% [markdown]
# back to [index](index.ipynb)

# %% [markdown]
# # odroid_imaging

# %% [markdown]
# 2014-07-19

# %% [markdown]
# * downloaded images from http://odroid.in/ubuntu_14.04lts/
# * specific urls:
#     * http://odroid.in/ubuntu_14.04lts/ubuntu-14.04lts-server-odroid-u-20140604.img.xz
#     * http://odroid.in/ubuntu_14.04lts/ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum
# * forum
#     * http://forum.odroid.com/viewforum.php?f=77
# * ROS Releases:
#     * 12.04
#     * 12.10
#     * 13.04

# %% [markdown]
# * how to odroid u3
#     * https://docs.google.com/document/d/18EGM_EvqFqWK6os5gj9I0v67tMrn7DTTpKlPGzaCvY0/edit#

# %%
# !ln -s ../images disk_images

# %%
ls disk_images/
# Out:
# linaro_ubuntu_13.05_server_U2.img.xz
# linaro_ubuntu_13.05_server_U2.img.xz.md5sum
# linux-3.0.60-odroidu2_20130128.tar.gz
# linux-3.0.60-odroidu2_20130128.tar.gz.md5sum
# odroidu2_20130125-linaro-ubuntu-desktop_SDeMMC.img.xz
# odroidu2_20130125-linaro-ubuntu-desktop_SDeMMC.img.xz.md5sum
# ubuntu-14.04lts-server-odroid-u-20140604.img.xz
# ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum
# zumy_122.img

# %% [markdown]
# #### Downloading images

# %%
# %%bash
# cd disk_images
# wget http://odroid.in/ubuntu_14.04lts/ubuntu-14.04lts-server-odroid-u-20140604.img.xz
# Out:
# --2014-10-15 13:45:13--  http://odroid.in/ubuntu_14.04lts/ubuntu-14.04lts-server-odroid-u-20140604.img.xz
# Resolving odroid.in (odroid.in)... 67.228.201.157
# Connecting to odroid.in (odroid.in)|67.228.201.157|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 177351372 (169M) [application/x-img]
# Saving to: `ubuntu-14.04lts-server-odroid-u-20140604.img.xz.1'
#
#      0K .......... .......... .......... .......... ..........  0% 1.44M 1m57s
#     50K .......... .......... .......... .......... ..........  0% 1.01M 2m22s
#    100K .......... .......... .......... .......... ..........  0% 2.05M 2m2s
#    150K .......... .......... .......... .......... ..........  0% 2.02M 1m53s
#    200K .......... .......... .......... .......... ..........  0% 2.11M 1m46s
#    250K .......... .......... .......... .......... ..........  0% 1.72M 1m45s
#    300K .......... .......... .......... .......... ..........  0% 8.26M 93s
# ...

# %%
# %%bash
# cd disk_images
# wget http://odroid.in/ubuntu_14.04lts/ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum
# Out:
# --2014-10-15 13:47:05--  http://odroid.in/ubuntu_14.04lts/ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum
# Resolving odroid.in (odroid.in)... 67.228.201.157
# Connecting to odroid.in (odroid.in)|67.228.201.157|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [application/x-img]
# Saving to: `ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum.1'
#
#      0K                                                       100% 6.30M=0s
#
# 2014-10-15 13:47:05 (6.30 MB/s) - `ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum.1' saved [88/88]

# %%
# !md5sum disk_images/ubuntu-14.04lts-server-odroid-u-20140604.img.xz
# Out:
# b7568e191eef679116e252ae5136ecee  disk_images/ubuntu-14.04lts-server-odroid-u-20140604.img.xz

# %%
# !cat disk_images/ubuntu-14.04lts-server-odroid-u-20140604.img.xz.md5sum
# Out:
# b7568e191eef679116e252ae5136ecee  ubuntu_server-14.04lts-armhf-ODROID-U-20140604.img.xz

# %% [markdown]
# #### Writing the image

# %% [markdown]
# this can't be done in the ipython notebook because it requires root.

# %% [markdown]
# ```bash
#
# xzcat ubuntu-14.04lts-server-odroid-u-20140604.img.xz | sudo dd of=/dev/mmcblk0 bs=4M
#
# sync # flush IO buffers
# ```
